# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url = "https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=SSD&page=1&sort=rnk/dc"
res = requests.get(url)
data = json.loads(res.text)

# %%
data
# Out:
# {'QTime': 158,
#  'totalRows': 7067,
#  'totalPage': 100,
#  'range': {'min': '', 'max': ''},
#  'cateName': '',
#  'q': 'SSD',
#  'subq': '',
#  'token': ['SSD'],
#  'prods': [{'Id': 'DRAH5E-A9007CRTN',
#    'cateId': 'DRAH7P',
#    'picS': '/items/DRAH5EA9007CRTN/000002_1488791017.jpg',
#    'picB': '/items/DRAH5EA9007CRTN/000001_1522202196.jpg',
#    'name': 'SanDisk SSD Plus 240GB 2.5吋SATAIII固態硬碟(G26)',
#    'describe': 'SanDisk 進化版 SSD Plus 240GB 2.5吋SATAIII固態硬碟\\r\\n讀530m 寫440m tlc 三年保\r\n★持續讀寫速度530mb s；440mb s\r\n★搭配sandisk頂級tlc同步顆粒\r\n★dashboard 軟體可即時監控裝置狀態及軟體更新\r\n★7mm薄型設計\r\n★三年保固\r\n★展碁國際公司貨',
#    'price': 1488,
#    'originPrice': 1488,
#    'author': '',
#    'brand': '',
#    'publishDate': '',
#    'sellerId': '',
#    'isPChome': 1,
#    'isNC17': 0,
#    'couponActid': [],
#    'BU': 'ec'},
#   {'Id': 'DRAH5W-A9008I75F',
#    'cateId': 'DRAH7P',
#    'picS': '/items/DRAH5WA9008I75F/000002_1509343838.jpg',
#    'picB': '/items/DRAH5WA9008I75F/000001_1509343838.jpg',
# ...

# %%
webdatas = data['prods']

# %%
len (webdatas)
# Out:
# 20

# %%
for product in webdatas :
    print (product['name'])
    print (product['price'])
# Out:
# SanDisk SSD Plus 240GB 2.5吋SATAIII固態硬碟(G26)
# 1488
# SanDisk SSD Plus 120GB 2.5吋SATAIII固態硬碟(G27)
# 888
# WD SSD 500GB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)
# 5699
# WD SSD 1TB 2.5吋 3D NAND固態硬碟(藍標)
# 6299
# WD SSD 500GB 2.5吋 3D NAND固態硬碟(藍標)
# 2899
# WD My Passport SSD 256GB 外接式固態硬碟(USB3.1)
# 2990
# SanDisk SSD Plus 480GB 2.5吋SATAIII固態硬碟(G26)
# 2588
# WD SSD 256GB M.2 2280 PCIe Gen3固態硬碟(黑標)
# 2399
# WD My Passport SSD 512GB 外接式固態硬碟(USB3.1)
# 4690
# WD SSD 1TB M.2 SATA 3D NAND固態硬碟(藍標)
# 6299
# WD SSD 1TB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)
# 11399
# WD SSD 256GB M.2 2280 PCIe Gen3固態硬碟(黑標)
# 2399
# WD SSD 250GB 2.5吋 3D NAND 固態硬碟(藍標)
# 1899
# WD SSD 500GB M.2 SATA 3D NAND固態硬碟(藍標)
# 2899
# SanDisk SSD Plus 960GB 2.5吋SATAIII固態硬碟
# 5990
# WD My Passport SSD 1TB 外接式固態硬碟(USB3.1)
# 9690
# 美光Micron Crucial BX300 480GB SATAⅢ固態硬碟
# 2599
# HyperX Savage Sata 3 240GB 2.5吋固態硬碟SSD (SHSS37A/240G)
# 3699
# WD SSD 250GB M.2 2280 NVMe PCIe Gen3 固態硬碟(黑標)
# 2999
# WD SSD 240GB 2.5吋固態硬碟(綠標)
# 1599
