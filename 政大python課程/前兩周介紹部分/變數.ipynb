# %%
a = 3

# %%
a + 7
# Out:
# 10

# %%
a
# Out:
# 3

# %%
a = 100

# %%
a
# Out:
# 100

# %%
import requests
res = requests.get("https://s.taobao.com/search?q=%E4%BF%9D%E6%BA%AB%E6%9D%AF&type=p&tmhkh5=&spm=a21wu.241046-tw.a2227oh.d100&from=sea_1_searchbutton&catId=100")
print (res.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN">
# <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="renderer" content="webkit">
#     <meta name="data-spm" content="a230r">
#     <link rel="dns-prefetch" href="//g.alicdn.com">
#     <link rel="dns-prefetch" href="//assets.alicdn.com">
#     <link rel="dns-prefetch" href="//img.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search1.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search2.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search3.alicdn.com">
#     <link rel="dns-prefetch" href="//g-search4.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms01.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms02.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms03.alicdn.com">
#     <link rel="dns-prefetch" href="//gtms04.alicdn.com">
#     <link rel="shortcut icon" href="//www.taobao.com/favicon.ico">
# ...

# %%
from bs4 import BeautifulSoup
html_sample = ' \
<html> \
<head> \
    <meta charset="UTF-8"> This is \
    <meta http-equiv="X-UA-Compatible" content="IE=edge"> \
    </body> \
</html>'
soup = BeautifulSoup(html_sample, 'lxml')
print (soup.contents)
# Out:
# [<html> <head> <meta charset="utf-8"/></head><body><p> This is     <meta content="IE=edge" http-equiv="X-UA-Compatible"/> </p></body> </html>]

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("https://s.taobao.com/search?q=%E4%BF%9D%E6%BA%AB%E6%9D%AF&type=p&tmhkh5=&spm=a21wu.241046-tw.a2227oh.d100&from=sea_1_searchbutton&catId=100")
soup = BeautifulSoup(res.text, "html.parser")
print (soup.select('.auctionPrices'))
# Out:
# []

# %%
html = '''
<html>
    <body>
        <h1 id="title">Hello World</h1>
        <a href="#link1" class="link">This is link1</a>
        <a href="#link2" class="link">This is link2</a>
    </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'html.parser')
#print (type(soup))
header = soup.select('.link')
#print (type(header))
print (header)
#print (header[0])
#print (type(header[0]))
#print (header[0].text)
# Out:
# [<a class="link" href="#link1">This is link1</a>, <a class="link" href="#link2">This is link2</a>]
